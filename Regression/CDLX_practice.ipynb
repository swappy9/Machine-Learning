# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Training.csv")

# %%
df.head()
# Out:
#        ID GDR  yrdob agegrp state    cregion  iyear  tx_b  tx_bs  tx_s  ...    \
# 0  100000   F   1958  45-54    NY  Northeast   2005     0      0     0  ...
# 1  100001   M   1944  55-64    TX      South   2006     1      0     0  ...
# 2  100002   F   1952  45-54    OH    Midwest   2005     0      0     0  ...
# 3  100004   F   1958  45-54    MD      South   2006     1      0     0  ...
# 4  100005   F   1939    65+    FL      South   2006     1      0     0  ...
#
#    pre_med_charges  pre_rx_charges  pre_tot_charges  tx_med_charges  \
# 0              660               0              660             397
# 1          116,153           1,250          117,402          87,676
# 2            2,114           1,014            3,128           3,138
# 3           36,606           6,675           43,281           6,349
# 4           13,496           3,565           17,062           3,420
#
#    tx_rx_charges  tx_tot_charges  post_med_charges  post_rx_charges  \
# 0            358             754                 5              456
# 1          1,894          89,569                11            2,144
# 2            973           4,111                 8              531
# 3            940           7,289                 9            1,512
# 4          1,560           4,980                11            4,520
#
#    post_tot_charges  compl
# 0               656      0
# 1            63,616      0
# 2             4,380      0
# 3             9,762      0
# 4            85,220      0
#
# [5 rows x 39 columns]

# %%
df.compl.value_counts()
# Out:
# 0    36130
# 1      676
# Name: compl, dtype: int64

# %%
df.describe()
# Out:
#                   ID         yrdob         iyear          tx_b         tx_bs  \
# count   36806.000000  36806.000000  36806.000000  36806.000000  36806.000000
# mean   128644.275825   1953.064908   2005.457561      0.256317      0.075069
# std     16972.415564     10.489782      0.498202      0.436605      0.263507
# min    100000.000000   1921.000000   2005.000000      0.000000      0.000000
# 25%    114002.250000   1946.000000   2005.000000      0.000000      0.000000
# 50%    128190.000000   1953.000000   2005.000000      0.000000      0.000000
# 75%    143707.750000   1960.000000   2006.000000      1.000000      0.000000
# max    166522.000000   1988.000000   2006.000000      1.000000      1.000000
#
#                tx_s          tx_z         tx_bz         tx_bd        tx_bsz  \
# count  36806.000000  36806.000000  36806.000000  36806.000000  36806.000000
# mean       0.055616      0.049394      0.071809      0.000897      0.023284
# std        0.229182      0.216692      0.258175      0.029930      0.150807
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#            ...              tx_bp       tx_life  num_pre_dx_grps  \
# count      ...       36806.000000  36806.000000     36806.000000
# mean       ...           0.002717      0.435663         0.905369
# std        ...           0.052054      0.495850         1.500581
# min        ...           0.000000      0.000000         0.000000
# 25%        ...           0.000000      0.000000         0.000000
# 50%        ...           0.000000      0.000000         0.000000
# 75%        ...           0.000000      1.000000         1.000000
# max        ...           1.000000      1.000000        20.000000
#
#        num_pre_rx_grps  num_tx_dx_grps  num_tx_rx_grps  num_post_dx_grps  \
# count     36806.000000    36806.000000    36806.000000      36806.000000
# mean          4.108298        1.524616        6.248003          1.659458
# std           3.858566        1.960728        4.003823          2.213098
# min           0.000000        0.000000        0.000000          0.000000
# 25%           1.000000        0.000000        3.000000          0.000000
# 50%           3.000000        1.000000        6.000000          1.000000
# 75%           6.000000        2.000000        8.000000          2.000000
# max          40.000000       35.000000       36.000000         30.000000
#
#        num_post_rx_grps  post_med_charges         compl
# count      36806.000000      36806.000000  36806.000000
# mean           6.731212          7.426235      0.018367
# std            4.623020          2.389644      0.134275
# min            0.000000          0.000000      0.000000
# 25%            4.000000          7.000000      0.000000
# 50%            6.000000          8.000000      0.000000
# 75%            9.000000          9.000000      0.000000
# max           38.000000         14.000000      1.000000
#
# [8 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36806 entries, 0 to 36805
# Data columns (total 39 columns):
# ID                  36806 non-null int64
# GDR                 36806 non-null object
# yrdob               36806 non-null int64
# agegrp              36806 non-null object
# state               36806 non-null object
# cregion             36806 non-null object
# iyear               36806 non-null int64
# tx_b                36806 non-null int64
# tx_bs               36806 non-null int64
# tx_s                36806 non-null int64
# tx_z                36806 non-null int64
# tx_bz               36806 non-null int64
# tx_bd               36806 non-null int64
# tx_bsz              36806 non-null int64
# tx_bs_plus          36806 non-null int64
# tx_bz_plus          36806 non-null int64
# tx_sz               36806 non-null int64
# tx_d                36806 non-null int64
# tx_oth              36806 non-null int64
# tx_b_plus           36806 non-null int64
# tx_p                36806 non-null int64
# tx_bp               36806 non-null int64
# tx_life             36806 non-null int64
# num_pre_dx_grps     36806 non-null int64
# num_pre_rx_grps     36806 non-null int64
# num_tx_dx_grps      36806 non-null int64
# num_tx_rx_grps      36806 non-null int64
# num_post_dx_grps    36806 non-null int64
# num_post_rx_grps    36806 non-null int64
# pre_med_charges     36806 non-null object
# pre_rx_charges      36806 non-null object
# pre_tot_charges     36806 non-null object
# tx_med_charges      36806 non-null object
# tx_rx_charges       36806 non-null object
# tx_tot_charges      36806 non-null object
# post_med_charges    36806 non-null int64
# post_rx_charges     36806 non-null object
# post_tot_charges    36806 non-null object
# compl               36806 non-null int64
# dtypes: int64(27), object(12)
# memory usage: 11.0+ MB

# %%
L = ['GDR','yrdob','agegrp','state','cregion']

sns.countplot(df['compl'])

# %%
for f in L:    
    fig, ax = plt.subplots(figsize=(10,5))
    # Calculate the percentage of target=1 per category value
    cat_perc = df[[f, 'compl']].groupby(by=f).agg({'compl':'sum'}).reset_index()
    cat_perc.sort_values(by='compl', ascending=False, inplace=True)
    x1 = cat_perc.columns[0]
    y1 = cat_perc.columns[1]
    sns.barplot(ax = ax, x = x1, y = y1, data=cat_perc, order=cat_perc[x1])
    #plt.ylabel('# target', fontsize=18)
    #plt.xlabel(f, fontsize=18)
    #plt.tick_params(axis='both', which='major', labelsize=18)

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.heatmap(df.corr() , annot=True)
